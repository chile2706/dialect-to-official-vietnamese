# %% [markdown]
# # Load Dataset

# %% [markdown]
# Ha Noi, Nghe An, Hue, Sai gon, [?]

# %%
# !pip install datasets
# !pip install pyarrow

from datasets import load_dataset
from IPython.display import Audio
import json
import pandas as pd

# %% [markdown]
# Ha Noi: 26 --> 28
#
# Nghe An: 33 --> 35
#
# Hue: 69 --> 70
#
# Sai Gon: 43 --> 45

# %%
# Saigon
# dataset = load_dataset("nguyendv02/ViMD_Dataset", data_files="data/train-00045-of-00103.parquet")['train']
# saigon_store = []
# n = len(dataset)
# for i in range(n):
#   if dataset[i]['province_name'] != 'HoChiMinh':
#     print(i)
#     break
for i in range(24):
  saigon_store.append(dataset[i])
# for i in range(70, n, 1):
#   saigon_store.append(dataset[i])

# %%
print(len(saigon_store))
print(saigon_store[171]['province_name'])
print(saigon_store[-1]['province_name'])
# Out:
# 270
# HoChiMinh
# HoChiMinh

# %%
# hanoi_store = []
# hanoi_store += list(dataset[103:])
# hanoi_store[0]
# dataset[103:105]
df = pd.DataFrame(saigon_store)
df.to_parquet(f"{path}saigon.parquet", engine="pyarrow", index=False)
# path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/CSCI_5541_project/'

# %%
# for i in range(100, 104, 1):
#   print(i)
#   file = f"data/train-00{i}-of-00103.parquet"
#   dataset = load_dataset("nguyendv02/ViMD_Dataset", data_files=file)['train']
#   # print(len(dataset))
#   print(dataset[0]['province_name'])
#   print(dataset[-1]['province_name'])
#   record = {
#       "file_name": file,
#       "first_record": dataset[0]['province_name'],
#       "last_record": dataset[-1]['province_name']
#   }
#   with open(path+"train_parquet.jsonl", "a") as f:  # Open in append mode
#         f.write(json.dumps(record) + "\n")
